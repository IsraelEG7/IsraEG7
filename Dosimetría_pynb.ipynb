# %% [markdown]
# <a href="https://colab.research.google.com/github/IsraelEG7/IsraEG7/blob/main/Dosimetr%C3%ADa_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from pandas.core.internals.managers import T
T1 = pd.read_csv("Tabla1 - Hoja1.csv") 
T2 = pd.read_csv("Tabla2 - Hoja1.csv")
T3 = pd.read_csv("Tabla3 - Hoja1.csv")

# %%
T1
# Out:
#                    Organo  Unnamed: 1  Unnamed: 2  Dosis (mGy)  \
# 0                  Vejiga         NaN         NaN         2.35
# 1       Superficies Oseas         NaN         NaN         1.75
# 2                    Mama         NaN         NaN         4.30
# 3                Estómago         NaN         NaN        18.60
# 4       Intentino Delgado         NaN         NaN         5.05
# 5   Intestino Grueso Alto         NaN         NaN         6.60
# 6   Intestino Grueso Bajo         NaN         NaN         2.15
# 7                 Riñones         NaN         NaN         3.35
# 8                  Hígado         NaN         NaN        12.70
# 9                Pulmones         NaN         NaN        11.10
# 10                Ovarios         NaN         NaN         3.15
# 11               Pancreas         NaN         NaN         8.65
# 12            Médula Roja         NaN         NaN         1.30
# 13             Testículos         NaN         NaN         1.25
# ...

# %%
T2
# Out:
#                     Radiación sintomas  Exposición en mSv
# 0  Sin sintomas riesgo mínmo de cáncer                 15
# 1  Sin síntomas a corto plazo visibles                 25
# 2                Intoxicación moderada                 50
# 3       Evidente cáncer y afectaciones                100
# 4              Mortal a un par de años               1000
# 5            Mortal a un ar de semanas               5000

# %%
T1.plot.barh(y= "Dosis (mGy)",x= "Equivalencia en años" )

# %%
T3
# Out:
#                    Organo  Unnamed: 1  Unnamed: 2  Dosis (mGy)  \
# 0                  Vejiga         NaN         NaN         2.35
# 1       Superficies Oseas         NaN         NaN         1.75
# 2                    Mama         NaN         NaN         4.30
# 3                Estómago         NaN         NaN        18.60
# 4       Intentino Delgado         NaN         NaN         5.05
# 5   Intestino Grueso Alto         NaN         NaN         6.60
# 6   Intestino Grueso Bajo         NaN         NaN         2.15
# 7                 Riñones         NaN         NaN         3.35
# 8                  Hígado         NaN         NaN        12.70
# 9                Pulmones         NaN         NaN        11.10
# 10                Ovarios         NaN         NaN         3.15
# 11               Pancreas         NaN         NaN         8.65
# 12            Médula Roja         NaN         NaN         1.30
# 13             Testículos         NaN         NaN         1.25
# ...

# %%
T3.plot.bar(y= "Dosis (mGy)",x="Exposición en mSv")
